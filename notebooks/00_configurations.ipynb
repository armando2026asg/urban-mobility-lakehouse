# %%
catalog = "mobility_dev"

#Schemas
bronze = f"{catalog}.bronze"
silver = f"{catalog}.silver"
gold = f"{catalog}.gold"

#Tables
bronze_sources_raw = f"{catalog}.bronze.urban_mobility_sources_raw"
silver_sources = f"{catalog}.silver.urban_mobility_sources"

# %%
landing_path =  "abfss://landing@sturbanmobilitydev001.dfs.core.windows.net/"
sources_path = f"{landing_path}reference/urban_mobility_sources/"
